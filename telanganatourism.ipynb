# %%
import pandas as pd
import numpy as np
import pandas as pd

# Use the pandas read_csv function to read the uploaded CSV file
file_path = '/domestic_visitors_2016.csv'  # Replace with the actual file name
df = pd.read_csv(file_path)
df
# Out:
#             district        date      month  year visitors
# 0           Adilabad  01-01-2016    January  2016   792136
# 1           Adilabad  01-02-2016   February  2016   937820
# 2           Adilabad  01-03-2016      March  2016   582946
# 3           Adilabad  01-04-2016      April  2016   341948
# 4           Adilabad  01-05-2016        May  2016   252887
# ..               ...         ...        ...   ...      ...
# 367  Yadadri Bhongir  01-08-2016     August  2016
# 368  Yadadri Bhongir  01-09-2016  September  2016
# 369  Yadadri Bhongir  01-10-2016    October  2016   584800
# 370  Yadadri Bhongir  01-11-2016   November  2016   681000
# 371  Yadadri Bhongir  01-12-2016   December  2016   462800
#
# [372 rows x 5 columns]

# %%
path1 = '/domestic_visitors_2017.csv'  # Replace with the actual file name
df1 = pd.read_csv(path1)
df1
# Out:
#             district        date      month  year visitors
# 0           Adilabad  01-01-2017    January  2017   318799
# 1           Adilabad  01-02-2017   February  2017    83316
# 2           Adilabad  01-03-2017      March  2017    27508
# 3           Adilabad  01-04-2017      April  2017    13946
# 4           Adilabad  01-05-2017        May  2017    11752
# ..               ...         ...        ...   ...      ...
# 367  Yadadri Bhongir  01-08-2017     August  2017   680720
# 368  Yadadri Bhongir  01-09-2017  September  2017   678925
# 369  Yadadri Bhongir  01-10-2017    October  2017   683500
# 370  Yadadri Bhongir  01-11-2017   November  2017   537600
# 371  Yadadri Bhongir  01-12-2017   December  2017   481075
#
# [372 rows x 5 columns]

# %%
path2 = '/domestic_visitors_2018.csv'  # Replace with the actual file name
df2 = pd.read_csv(path2)
df2
# Out:
#             district        date      month  year visitors
# 0           Adilabad  01-01-2018    January  2018   320356
# 1           Adilabad  01-02-2018   February  2018    36550
# 2           Adilabad  01-03-2018      March  2018    23011
# 3           Adilabad  01-04-2018      April  2018    14183
# 4           Adilabad  01-05-2018        May  2018     8197
# ..               ...         ...        ...   ...      ...
# 367  Yadadri Bhongir  01-08-2018     August  2018   526445
# 368  Yadadri Bhongir  01-09-2018  September  2018   819350
# 369  Yadadri Bhongir  01-10-2018    October  2018   586475
# 370  Yadadri Bhongir  01-11-2018   November  2018   485208
# 371  Yadadri Bhongir  01-12-2018   December  2018   606510
#
# [372 rows x 5 columns]

# %%
path3 = '/domestic_visitors_2019.csv'  # Replace with the actual file name
df3 = pd.read_csv(path3)
df3
# Out:
#             district        date      month  year visitors
# 0           Adilabad  01-01-2019    January  2019    25071
# 1           Adilabad  01-02-2019   February  2019   406177
# 2           Adilabad  01-03-2019      March  2019    14347
# 3           Adilabad  01-04-2019      April  2019     9972
# 4           Adilabad  01-05-2019        May  2019     6997
# ..               ...         ...        ...   ...      ...
# 391  Yadadri Bhongir  01-08-2019     August  2019   389010
# 392  Yadadri Bhongir  01-09-2019  September  2019   366862
# 393  Yadadri Bhongir  01-10-2019    October  2019   381860
# 394  Yadadri Bhongir  01-11-2019   November  2019   365990
# 395  Yadadri Bhongir  01-12-2019   December  2019   477635
#
# [396 rows x 5 columns]

# %%
domestic = pd.concat([df, df1, df2, df3], ignore_index=True)
domestic
# Out:
#              district        date      month  year visitors
# 0            Adilabad  01-01-2016    January  2016   792136
# 1            Adilabad  01-02-2016   February  2016   937820
# 2            Adilabad  01-03-2016      March  2016   582946
# 3            Adilabad  01-04-2016      April  2016   341948
# 4            Adilabad  01-05-2016        May  2016   252887
# ...               ...         ...        ...   ...      ...
# 1507  Yadadri Bhongir  01-08-2019     August  2019   389010
# 1508  Yadadri Bhongir  01-09-2019  September  2019   366862
# 1509  Yadadri Bhongir  01-10-2019    October  2019   381860
# 1510  Yadadri Bhongir  01-11-2019   November  2019   365990
# 1511  Yadadri Bhongir  01-12-2019   December  2019   477635
#
# [1512 rows x 5 columns]

# %%
domestic.shape
# Out:
# (1512, 5)

# %%
domestic.isnull().sum()
# Out:
# district     0
# date         0
# month        0
# year         0
# visitors    30
# dtype: int64

# %%
domestic.replace([" ",np.nan], 0, inplace=True)
domestic
# Out:
#              district        date      month  year visitors
# 0            Adilabad  01-01-2016    January  2016   792136
# 1            Adilabad  01-02-2016   February  2016   937820
# 2            Adilabad  01-03-2016      March  2016   582946
# 3            Adilabad  01-04-2016      April  2016   341948
# 4            Adilabad  01-05-2016        May  2016   252887
# ...               ...         ...        ...   ...      ...
# 1507  Yadadri Bhongir  01-08-2019     August  2019   389010
# 1508  Yadadri Bhongir  01-09-2019  September  2019   366862
# 1509  Yadadri Bhongir  01-10-2019    October  2019   381860
# 1510  Yadadri Bhongir  01-11-2019   November  2019   365990
# 1511  Yadadri Bhongir  01-12-2019   December  2019   477635
#
# [1512 rows x 5 columns]

# %%
domestic.isnull().sum()
# Out:
# district    0
# date        0
# month       0
# year        0
# visitors    0
# dtype: int64

# %%
domestic.dtypes
# Out:
# district    object
# date        object
# month       object
# year         int64
# visitors    object
# dtype: object

# %%
domestic['visitors']=domestic.visitors.astype("int64")
domestic.dtypes
# Out:
# district    object
# date        object
# month       object
# year         int64
# visitors     int64
# dtype: object

# %%
domestic.groupby("district")["visitors"].sum().sort_values(ascending=True).nlargest(10)
# Out:
# district
# Hyderabad                   83900960
# Rajanna Sircilla            41763276
# Warangal (Urban)            30726603
# Yadadri Bhongir             26893080
# Bhadradri Kothagudem        21600962
# Medak                       20542639
# Jayashankar Bhoopalpally    19632865
# Mahbubnagar                 17180118
# Nirmal                      13315796
# Jagtial                     11303514
# Name: visitors, dtype: int64

# %%
dff = pd.read_csv('/foreign_visitors_2016.csv')
dff
# Out:
#             district        date      month  year visitors
# 0           Adilabad  01-01-2016    January  2016        2
# 1           Adilabad  01-02-2016   February  2016        0
# 2           Adilabad  01-03-2016      March  2016        2
# 3           Adilabad  01-04-2016      April  2016        0
# 4           Adilabad  01-05-2016        May  2016        0
# ..               ...         ...        ...   ...      ...
# 367  Yadadri Bhongir  01-08-2016     August  2016
# 368  Yadadri Bhongir  01-09-2016  September  2016
# 369  Yadadri Bhongir  01-10-2016    October  2016        0
# 370  Yadadri Bhongir  01-11-2016   November  2016        0
# 371  Yadadri Bhongir  01-12-2016   December  2016        0
#
# [372 rows x 5 columns]

# %%
dff1 = pd.read_csv('/foreign_visitors_2017.csv')
dff1
# Out:
#             district        date      month  year visitors
# 0           Adilabad  01-01-2017    January  2017        5
# 1           Adilabad  01-02-2017   February  2017        0
# 2           Adilabad  01-03-2017      March  2017        0
# 3           Adilabad  01-04-2017      April  2017        0
# 4           Adilabad  01-05-2017        May  2017        0
# ..               ...         ...        ...   ...      ...
# 367  Yadadri Bhongir  01-08-2017     August  2017        0
# 368  Yadadri Bhongir  01-09-2017  September  2017        0
# 369  Yadadri Bhongir  01-10-2017    October  2017        0
# 370  Yadadri Bhongir  01-11-2017   November  2017        0
# 371  Yadadri Bhongir  01-12-2017   December  2017        0
#
# [372 rows x 5 columns]

# %%
dff2 = pd.read_csv('/foreign_visitors_2018.csv')
dff2
# Out:
#             district        date      month  year visitors
# 0           Adilabad  01-01-2018    January  2018        0
# 1           Adilabad  01-02-2018   February  2018        0
# 2           Adilabad  01-03-2018      March  2018        0
# 3           Adilabad  01-04-2018      April  2018        0
# 4           Adilabad  01-05-2018        May  2018        0
# ..               ...         ...        ...   ...      ...
# 367  Yadadri Bhongir  01-08-2018     August  2018        0
# 368  Yadadri Bhongir  01-09-2018  September  2018        0
# 369  Yadadri Bhongir  01-10-2018    October  2018        0
# 370  Yadadri Bhongir  01-11-2018   November  2018        0
# 371  Yadadri Bhongir  01-12-2018   December  2018        0
#
# [372 rows x 5 columns]

# %%
dff3= pd.read_csv('/foreign_visitors_2019.csv')
dff3
# Out:
#             district        date      month  year visitors
# 0           Adilabad  01-01-2019    January  2019        0
# 1           Adilabad  01-02-2019   February  2019        2
# 2           Adilabad  01-03-2019      March  2019        0
# 3           Adilabad  01-04-2019      April  2019        0
# 4           Adilabad  01-05-2019        May  2019        0
# ..               ...         ...        ...   ...      ...
# 391  Yadadri Bhongir  01-08-2019     August  2019        0
# 392  Yadadri Bhongir  01-09-2019  September  2019        0
# 393  Yadadri Bhongir  01-10-2019    October  2019        0
# 394  Yadadri Bhongir  01-11-2019   November  2019        0
# 395  Yadadri Bhongir  01-12-2019   December  2019        0
#
# [396 rows x 5 columns]

# %%
foreign = pd.concat([dff,dff1,dff2,dff3],ignore_index=True)
foreign
# Out:
#              district        date      month  year visitors
# 0            Adilabad  01-01-2016    January  2016        2
# 1            Adilabad  01-02-2016   February  2016        0
# 2            Adilabad  01-03-2016      March  2016        2
# 3            Adilabad  01-04-2016      April  2016        0
# 4            Adilabad  01-05-2016        May  2016        0
# ...               ...         ...        ...   ...      ...
# 1507  Yadadri Bhongir  01-08-2019     August  2019        0
# 1508  Yadadri Bhongir  01-09-2019  September  2019        0
# 1509  Yadadri Bhongir  01-10-2019    October  2019        0
# 1510  Yadadri Bhongir  01-11-2019   November  2019        0
# 1511  Yadadri Bhongir  01-12-2019   December  2019        0
#
# [1512 rows x 5 columns]

# %%
foreign.isnull().sum()
# Out:
# district    0
# date        0
# month       0
# year        0
# visitors    0
# dtype: int64

# %%
foreign["visitors"] = foreign["visitors"].replace(" ",0)
foreign["visitors"] = foreign["visitors"].astype("int64")

# %%
dt = pd.DataFrame({"foreign":foreign.groupby("district")["visitors"].sum()})
dt["domestic"]=domestic.groupby("district")["visitors"].sum()
dt.isnull().sum()
# Out:
# foreign     0
# domestic    1
# dtype: int64

# %%
dt["domestic"] = dt["domestic"].replace(np.nan, 0)
dt
# Out:
#                           foreign    domestic
# district
# Adilabad                       32   7321575.0
# Bhadradri Kothagudem            0  21600962.0
# Hyderabad                 1044898  83900960.0
# Jagtial                         0  11303514.0
# Jangaon                         2    826280.0
# Jayashankar Bhoopalpally     1252  19632865.0
# Jogulamba Gadwal              945   6813340.0
# Kamareddy                       0      1773.0
# Karimnagar                      0   9462383.0
# Khammam                         0   9378315.0
# Komaram Bheem Asifabad          0     92734.0
# Mahabubabad                     0    600697.0
# Mahbubnagar                  2282  17180118.0
# Mancherial                     10    867242.0
# Medak                           0  20542639.0
# Medchal                         0         0.0
# Mulugu                        575   1819800.0
# Nagarkurnool                  761   7424355.0
# Nalgonda                        0   6401933.0
# Narayanpet                      5         0.0
# Nirmal                          2  13315796.0
# Nizamabad                       5    116147.0
# Peddapalli                      0     56977.0
# Rajanna Sircilla                0  41763276.0
# Ranga Reddy                     0         0.0
# Sangareddy                      0  10424510.0
# Siddipet                        0   5775285.0
# Suryapet                        0         0.0
# Vikarabad                       0         0.0
# Wanaparthy                      0    890078.0
# Warangal (Rural)              306    819162.0
# Warangal (Urban)             8821  30726603.0
# Yadadri Bhongir                 0  26893080.0

# %%
total=domestic.append(foreign)
# Out:
# <ipython-input-31-aae6996a2d04>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   total=domestic.append(foreign)

# %%
total.shape
# Out:
# (3024, 5)

# %%
foreign.shape
# Out:
# (1512, 5)

# %%
domestic.shape
# Out:
# (1512, 5)

# %%
total
# Out:
#              district        date      month  year  visitors
# 0            Adilabad  01-01-2016    January  2016    792136
# 1            Adilabad  01-02-2016   February  2016    937820
# 2            Adilabad  01-03-2016      March  2016    582946
# 3            Adilabad  01-04-2016      April  2016    341948
# 4            Adilabad  01-05-2016        May  2016    252887
# ...               ...         ...        ...   ...       ...
# 1507  Yadadri Bhongir  01-08-2019     August  2019         0
# 1508  Yadadri Bhongir  01-09-2019  September  2019         0
# 1509  Yadadri Bhongir  01-10-2019    October  2019         0
# 1510  Yadadri Bhongir  01-11-2019   November  2019         0
# 1511  Yadadri Bhongir  01-12-2019   December  2019         0
#
# [3024 rows x 5 columns]

# %% [markdown]
# **TOP** ***10*** **DISTRICTS** **HAVING** **HIGHEST** **VISITORS**

# %%
total.groupby("district")["visitors"].sum().sort_values(ascending=True).nlargest(10).plot(kind="barh", title="Top 10 Districts")
# Out:
# <Axes: title={'center': 'Top 10 Districts'}, ylabel='district'>

# %%
total.groupby("district")["visitors"].sum().sort_values(ascending=True).nsmallest(10).plot(kind="barh", title="Top 10 Districts")
# Out:
# <Axes: title={'center': 'Top 10 Districts'}, ylabel='district'>

# %%
total.groupby("district")["visitors"].sum().nsmallest(10)
# Out:
# district
# Medchal                        0
# Ranga Reddy                    0
# Suryapet                       0
# Vikarabad                      0
# Narayanpet                     5
# Kamareddy                   1773
# Peddapalli                 56977
# Komaram Bheem Asifabad     92734
# Nizamabad                 116152
# Narayanapet               389250
# Name: visitors, dtype: int64

# %%
domestic.groupby("district")["visitors"].sum().sort_values(ascending=True).nlargest(10).plot(kind="barh", title="Top 10 Districts")
# Out:
# <Axes: title={'center': 'Top 10 Districts'}, ylabel='district'>

# %%
domestic.groupby(["year","district"])["visitors"].sum()
# Out:
# year  district
# 2016  Adilabad                  5075557
#       Bhadradri Kothagudem       889030
#       Hyderabad                23394705
#       Jagtial                    623077
#       Jangaon                     40660
#                                  ...
# 2019  Vikarabad                       0
#       Wanaparthy                 298639
#       Warangal (Rural)           353500
#       Warangal (Urban)          1795230
#       Yadadri Bhongir           4489374
# Name: visitors, Length: 126, dtype: int64

# %%
districts=domestic["district"].unique()
districts
# Out:
# array(['Adilabad', 'Bhadradri Kothagudem ', 'Hyderabad', 'Jagtial ',
#        'Jangaon ', 'Jayashankar Bhoopalpally', 'Jogulamba Gadwal ',
#        'Kamareddy ', 'Karimnagar ', 'Khammam', 'Komaram Bheem Asifabad',
#        'Mahabubabad ', 'Mahbubnagar', 'Mancherial', 'Medak ', 'Medchal ',
#        'Nagarkurnool ', 'Nalgonda', 'Nirmal', 'Nizamabad', 'Peddapalli',
#        'Rajanna Sircilla ', 'Ranga Reddy', 'Sangareddy ', 'Siddipet',
#        'Suryapet', 'Vikarabad', 'Wanaparthy ', 'Warangal (Rural)',
#        'Warangal (Urban)', 'Yadadri Bhongir', 'Mulugu', 'Narayanapet'],
#       dtype=object)

# %%
dom = pd.DataFrame({"district":districts})

# %%
domo_2016=[]
for i in districts:
    domestic_2016 = domestic[domestic["year"]==2016]
    domo = domestic_2016[domestic_2016["district"]==i].visitors.sum()
    domo_2016.append(domo)
dom["2016"]=domo_2016

# %%
domo_2019=[]
for i in districts:
    domestic_2019 = domestic[domestic["year"]==2019]
    domo = domestic_2019[domestic_2019["district"]==i].visitors.sum()
    domo_2019.append(domo)
dom["2019"]=domo_2019

# %%
dom.head()
# Out:
#                 district      2016      2019
# 0               Adilabad   5075557    775895
# 1  Bhadradri Kothagudem     889030  12817737
# 2              Hyderabad  23394705  13802362
# 3               Jagtial     623077   3086115
# 4               Jangaon      40660    328890

# %%
cagr=[]
for i in range(len(districts)):
    fv = dom.loc[i,"2019"]
    iv = dom.loc[i,"2016"]
    cagrr = (((fv/iv)**(1/3))-1)
    cagr.append(cagrr)
# Out:
# <ipython-input-46-b652aae79c70>:5: RuntimeWarning: divide by zero encountered in long_scalars
#   cagrr = (((fv/iv)**(1/3))-1)
# <ipython-input-46-b652aae79c70>:5: RuntimeWarning: invalid value encountered in long_scalars
#   cagrr = (((fv/iv)**(1/3))-1)

# %%
dom["CAGR"]=cagr

# %%
dom = dom.replace([np.inf,np.nan],0)

# %%
dom.head()
# Out:
#                 district      2016      2019      CAGR
# 0               Adilabad   5075557    775895 -0.465305
# 1  Bhadradri Kothagudem     889030  12817737  1.433875
# 2              Hyderabad  23394705  13802362 -0.161290
# 3               Jagtial     623077   3086115  0.704604
# 4               Jangaon      40660    328890  1.007372

# %%
dom_max = dom.sort_values(by="CAGR", ascending=False).head(3)
dom_max = dom_max.reset_index()
dom_max.drop("index", axis=1, inplace=True)

# %%
dom_max.head().plot("district", "CAGR", kind="bar")
# Out:
# <Axes: xlabel='district'>

# %% [markdown]
#  **BOTTOM 3 DISTRICTS CAGR**

# %%
dom_min = dom.sort_values(by="CAGR", ascending=True).head(3)
dom_min = dom_min.reset_index()
dom_min.drop("index", axis=1, inplace=True)

# %%
dom_min.head().plot("district", "CAGR", kind="bar")
# Out:
# <Axes: xlabel='district'>

# %% [markdown]
# **TOP 3 DISTRICTS **CAGR** **

# %%
dom_max = dom.sort_values(by="CAGR", ascending=False).head(3)
dom_max = dom_max.reset_index()
dom_max.drop("index", axis=1, inplace=True)

# %%
dom_max.head().plot("district", "CAGR", kind="bar")
# Out:
# <Axes: xlabel='district'>

# %%
dom.to_csv("cagr.csv")

# %% [markdown]
# **foreign top 3 CAGR**

# %%
foreign.groupby(["year","district"])["visitors"].sum()
# Out:
# year  district
# 2016  Adilabad                     10
#       Bhadradri Kothagudem          0
#       Hyderabad                163631
#       Jagtial                       0
#       Jangaon                       2
#                                 ...
# 2019  Vikarabad                     0
#       Wanaparthy                    0
#       Warangal (Rural)              0
#       Warangal (Urban)           2450
#       Yadadri Bhongir               0
# Name: visitors, Length: 126, dtype: int64

# %%
frgn = pd.DataFrame({"district":districts})

# %%
domo_2016=[]
for i in districts:
    domestic_2016 = foreign[foreign["year"]==2016]
    domo = domestic_2016[domestic_2016["district"]==i].visitors.sum()
    domo_2016.append(domo)
frgn["2016"]=domo_2016

# %%
domo_2019=[]
for i in districts:
    domestic_2019 = foreign[foreign["year"]==2019]
    domo = domestic_2019[domestic_2019["district"]==i].visitors.sum()
    domo_2019.append(domo)
frgn["2019"]=domo_2019

# %%
frgn.head()
# Out:
#                 district    2016    2019
# 0               Adilabad      10       6
# 1  Bhadradri Kothagudem        0       0
# 2              Hyderabad  163631  319300
# 3               Jagtial        0       0
# 4               Jangaon        2       0

# %%
cagr=[]
for i in range(len(districts)):
    fv = frgn.loc[i,"2019"]
    iv = frgn.loc[i,"2016"]
    cagrr = (((fv/iv)**(1/3))-1)
    cagr.append(cagrr)
# Out:
# <ipython-input-62-fa563c011814>:5: RuntimeWarning: invalid value encountered in long_scalars
#   cagrr = (((fv/iv)**(1/3))-1)
# <ipython-input-62-fa563c011814>:5: RuntimeWarning: divide by zero encountered in long_scalars
#   cagrr = (((fv/iv)**(1/3))-1)

# %%
frgn["CAGR"]=cagr

# %%
frgn.head()
# Out:
#                 district    2016    2019      CAGR
# 0               Adilabad      10       6 -0.156567
# 1  Bhadradri Kothagudem        0       0       NaN
# 2              Hyderabad  163631  319300  0.249619
# 3               Jagtial        0       0       NaN
# 4               Jangaon        2       0 -1.000000

# %%
frgn = frgn.replace([np.inf,np.nan],0)

# %%
frgn.head()
# Out:
#                 district    2016    2019      CAGR
# 0               Adilabad      10       6 -0.156567
# 1  Bhadradri Kothagudem        0       0  0.000000
# 2              Hyderabad  163631  319300  0.249619
# 3               Jagtial        0       0  0.000000
# 4               Jangaon        2       0 -1.000000

# %%
frgn.sort_values(by="CAGR", ascending=False)
# Out:
#                     district    2016    2019      CAGR
# 16             Nagarkurnool       29     199  0.900283
# 6          Jogulamba Gadwal       45     295  0.871557
# 2                  Hyderabad  163631  319300  0.249619
# 29          Warangal (Urban)    1899    2450  0.088630
# 25                  Suryapet       0       0  0.000000
# 20                Peddapalli       0       0  0.000000
# 21         Rajanna Sircilla        0       0  0.000000
# 22               Ranga Reddy       0       0  0.000000
# 23               Sangareddy        0       0  0.000000
# 24                  Siddipet       0       0  0.000000
# 27               Wanaparthy        0       0  0.000000
# 26                 Vikarabad       0       0  0.000000
# 18                    Nirmal       0       0  0.000000
# 28          Warangal (Rural)       0       0  0.000000
# 30           Yadadri Bhongir       0       0  0.000000
# 31                    Mulugu       0     575  0.000000
# 19                 Nizamabad       0       1  0.000000
# 32               Narayanapet       0       0  0.000000
# 17                  Nalgonda       0       0  0.000000
# 1      Bhadradri Kothagudem        0       0  0.000000
# 15                  Medchal        0       0  0.000000
# 14                    Medak        0       0  0.000000
# 13                Mancherial       0      10  0.000000
# 11              Mahabubabad        0       0  0.000000
# 10    Komaram Bheem Asifabad       0       0  0.000000
# 9                    Khammam       0       0  0.000000
# 8                Karimnagar        0       0  0.000000
# 7                 Kamareddy        0       0  0.000000
# 3                   Jagtial        0       0  0.000000
# 0                   Adilabad      10       6 -0.156567
# 5   Jayashankar Bhoopalpally      86      45 -0.194180
# 12               Mahbubnagar     868     440 -0.202659
# 4                   Jangaon        2       0 -1.000000

# %%
frgn_max = frgn.sort_values(by="CAGR", ascending=False).head(3)
frgn_max = frgn_max.reset_index()
frgn_max.drop("index", axis=1, inplace=True)

# %%
frgn_max
# Out:
#             district    2016    2019      CAGR
# 0      Nagarkurnool       29     199  0.900283
# 1  Jogulamba Gadwal       45     295  0.871557
# 2          Hyderabad  163631  319300  0.249619

# %%
frgn_max.head().plot("district", "CAGR", kind="bar")
# Out:
# <Axes: xlabel='district'>

# %% [markdown]
# **foreign bottom 3 CAGR**

# %%
frgn_min = frgn.sort_values(by="CAGR", ascending=True).head(3)
frgn_min = frgn_min.reset_index()
frgn_min.drop("index", axis=1, inplace=True)

# %%
frgn_min.head().plot("district", "CAGR", kind="bar")
# Out:
# <Axes: xlabel='district'>

# %%
frgn.to_csv("foreign_cagr.csv")

# %% [markdown]
# **PEAK MONTHS**

# %%
dom_hyd = domestic[domestic["district"]=="Hyderabad"]

# %%
dom_hyd.groupby("month")["visitors"].sum().sort_values(ascending=False).head()
# Out:
# month
# June        16897783
# December     9338637
# October      6552397
# January      6452101
# April        6126839
# Name: visitors, dtype: int64

# %%
dom_hyd.groupby("month")["visitors"].sum().sort_values(ascending=False).head().plot(kind="bar")
# Out:
# <Axes: xlabel='month'>

# %%
dom_hyd.groupby("month")["visitors"].sum().sort_values(ascending=False).tail()
# Out:
# month
# November     5626156
# July         5552527
# September    5312283
# March        5227626
# February     5014430
# Name: visitors, dtype: int64

# %%
dom_hyd.groupby("month")["visitors"].sum().sort_values(ascending=False).tail().plot(kind="bar")
# Out:
# <Axes: xlabel='month'>
